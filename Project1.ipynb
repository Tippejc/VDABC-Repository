# %%
# Dependencies

# %matplotlib notebook

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Create a path to the csv and read it into a Pandas DataFrame
csv_path = "Resources/CumulativeEmissions.csv"

cumulativeemissions_df = pd.read_csv (csv_path)




cumulativeemissions_df.head(50)
# Out:
#             Entity Code  Year  Cumulative CO₂ emissions by nation (tonnes)
# 0            China  CHN  2014                                   1.708770e+11
# 1            China  CHN  2015                                   1.805930e+11
# 2            China  CHN  2016                                   1.902980e+11
# 3            China  CHN  2017                                   2.001360e+11
# 4            India  IND  2014                                   4.143724e+10
# 5            India  IND  2015                                   4.371365e+10
# 6            India  IND  2016                                   4.609110e+10
# 7            India  IND  2017                                   4.855786e+10
# 8            Japan  JPN  2014                                   5.867156e+10
# 9            Japan  JPN  2015                                   5.989523e+10
# 10           Japan  JPN  2016                                   6.109955e+10
# ...

# %%
# Extract year from last 4 characters of each column name
years = data.columns.str.strip('Year')
# Convert year values to integers, saving results back to dataframe

# %%
my_plot = data.plot (kind= 'bar')
plt.title ('Cumulative Emissioins by Nation')
plt.ylabel ('Emissions totals by Nations')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0, 0.5, 'Emissions totals by Nations')
